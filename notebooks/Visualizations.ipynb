# %% [markdown]
# <a href="https://colab.research.google.com/github/SushiFou/ML-Business-Case-Project/blob/main/notebooks/Visualizations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <div align="center"><b> Machine Learning Business Case Project </b></div>
# ---
# <div align="center">Authors : Maxime Lepeytre | Soumaya Sabry | Alexandre Zajac | Olivier Boivin | Yann Kervella
#
#
# <center>
# <img src="https://github.com/SushiFou/ML-Business-Case-Project/blob/main/cover_image_tech.jpg?raw=1" width="800px"/>
# </center>
# </div>

# %% [markdown]
# <div align="center"><font color='red' size='12'> DON'T FORGET TO COMMIT CHANGES ON GITHUB FOLKS ! Good luck ! <font></div>

# %% [markdown]
# ## Context

# %% [markdown]
# Vous êtes consultant data scientist dans une grande entreprise de conseil
# française. Votre client est une entreprise qui génère beaucoup de données
# mais pour le moment aucun modèle de Machine Learning n'a été mis en
# place pour les exploiter. Elle a donc naturellement fait appel à vous.
#
# L’entreprise en question exploite plus de 3 000 magasins dans 7 pays
# européens. Actuellement, les directeurs de magasin sont chargés d’estimer
# leurs ventes quotidiennes jusqu'à six semaines à l'avance. Les ventes des
# magasins sont influencées par de nombreux facteurs, notamment les
# promotions, la concurrence, les vacances scolaires, la saisonnalité et la
# localité. Avec des milliers de gestionnaires individuels prédisant les ventes
# en fonction de leur situation particulière, la précision des résultats peut
# être très variable.
#
# Avec votre équipe de consultant data scientists, vous récupérez les
# données disponibles et allez mener un projet complet pour les exploiter et
# répondre à la problématique. Vous devez préparer et soutenir, pour le 21
# janvier 2021, un rendu sous forme de slides qui tirera les conclusions de
# votre travail, incluant une démonstration présentant les résultats du
# modèle de Machine Learning de manière visuelle à destination des
# utilisateur finaux. Vous aurez 12 minutes pour présenter votre travail à
# votre donneur d’ordre client.

# %% [markdown]
# ## Requirements

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
# Graphical settings
CB91_Blue = '#2CBDFE'
CB91_Green = '#47DBCD'
CB91_Pink = '#F3A0F2'
CB91_Purple = '#9D2EC5'
CB91_Violet = '#661D98'
CB91_Amber = '#F5B14C'
color_list = [CB91_Blue, CB91_Pink, CB91_Amber, CB91_Purple, CB91_Green,
              CB91_Violet]
params = {"ytick.color" : "w",
          "xtick.color" : "w",
          'axes.labelsize' : 15,
          "axes.labelcolor" : "w",
          "axes.edgecolor" : "w",
          "axes.titlecolor": "w", 
          'figure.figsize': [20, 8], 
          'axes.prop_cycle': plt.cycler(color=color_list), 
          'figure.dpi' : 75, 
          'legend.fontsize': 10,
          'font.size': 15 
          }
plt.rcParams.update(params)

# %% [markdown]
# ## Data Importation

# %% [markdown]
# ### gdown if using colab

# %%
# !gdown "https://drive.google.com/uc?id=1IHr_vKHZ0P0lUIAksJ9joRLUoUtZdDSY"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1IHr_vKHZ0P0lUIAksJ9joRLUoUtZdDSY
# To: /content/store.csv
# 100% 45.0k/45.0k [00:00<00:00, 16.8MB/s]

# %%
# !gdown "https://drive.google.com/uc?id=17ur-ILBNAZDgjpqgPU1XBLYSIXc5cn5d"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=17ur-ILBNAZDgjpqgPU1XBLYSIXc5cn5d
# To: /content/test.csv
# 100% 1.43M/1.43M [00:00<00:00, 94.3MB/s]

# %%
# !gdown "https://drive.google.com/uc?id=1kx5sSTcRj4aVS8KZgSCcdo9-5i1axh5n"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1kx5sSTcRj4aVS8KZgSCcdo9-5i1axh5n
# To: /content/train.csv
# 38.1MB [00:00, 57.2MB/s]

# %%
# !gdown "https://drive.google.com/uc?id=10p7JyO2DNkWbMRZoMNVPmipy1msZpBEV"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=10p7JyO2DNkWbMRZoMNVPmipy1msZpBEV
# To: /content/variables.txt
# 100% 1.58k/1.58k [00:00<00:00, 5.37MB/s]

# %% [markdown]
# ## Data Exploration

# %%
f = open("variables.txt", "r")
print(f.read())
# Out:
# Most of the fields are self-explanatory. The following are descriptions for those that aren't.
#
# Id - an Id that represents a (Store, Date) duple within the test set
# Store - a unique Id for each store
# Sales - the turnover for any given day
# Customers - the number of customers on a given day
# Open - an indicator for whether the store was open: 0 = closed, 1 = open
# StateHoliday - indicates a state holiday. Normally all stores, with few exceptions, are closed on state holidays. Note that all schools are closed on public holidays and weekends. a = public holiday, b = Easter holiday, c = Christmas, 0 = None
# SchoolHoliday - indicates if the (Store, Date) was affected by the closure of public schools
# StoreType - differentiates between 4 different store models: a, b, c, d
# Assortment - describes an assortment level: a = basic, b = extra, c = extended
# CompetitionDistance - distance in meters to the nearest competitor store
# ...

# %%
store_data = pd.read_csv('store.csv')
print(f'Dataframe shape : rows = {store_data.shape[0]}, columns = {store_data.shape[1]}')
store_data.head()
# Out:
# Dataframe shape : rows = 1115, columns = 10
#    Store StoreType  ... Promo2SinceYear    PromoInterval
# 0      1         c  ...             NaN              NaN
# 1      2         a  ...          2010.0  Jan,Apr,Jul,Oct
# 2      3         a  ...          2011.0  Jan,Apr,Jul,Oct
# 3      4         c  ...             NaN              NaN
# 4      5         a  ...             NaN              NaN
#
# [5 rows x 10 columns]

# %%
train_data = pd.read_csv('train.csv', low_memory = False)
print(f'Dataframe shape : rows = {train_data.shape[0]}, columns = {train_data.shape[1]}')
train_data.head()
# Out:
# Dataframe shape : rows = 1017209, columns = 9
#    Store  DayOfWeek        Date  Sales  ...  Open  Promo  StateHoliday SchoolHoliday
# 0      1          5  2015-07-31   5263  ...     1      1             0             1
# 1      2          5  2015-07-31   6064  ...     1      1             0             1
# 2      3          5  2015-07-31   8314  ...     1      1             0             1
# 3      4          5  2015-07-31  13995  ...     1      1             0             1
# 4      5          5  2015-07-31   4822  ...     1      1             0             1
#
# [5 rows x 9 columns]

# %% [markdown]
# ### Check Nan Values

# %%
store_data.isna().sum()
# Out:
# Store                          0
# StoreType                      0
# Assortment                     0
# CompetitionDistance            3
# CompetitionOpenSinceMonth    354
# CompetitionOpenSinceYear     354
# Promo2                         0
# Promo2SinceWeek              544
# Promo2SinceYear              544
# PromoInterval                544
# dtype: int64

# %% [markdown]
# Only 3 Nan values in competition distance
#
# A lot of nan due to no competition registered for some tuples

# %%
train_data.isna().sum()
# Out:
# Store            0
# DayOfWeek        0
# Date             0
# Sales            0
# Customers        0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# dtype: int64

# %%
store_data['CompetitionDistance'].fillna(store_data['CompetitionDistance'].mean(), inplace = True)

# %%
store_data.fillna(-1, inplace=True)

# %%
store_data.isna().sum()
# Out:
# Store                        0
# StoreType                    0
# Assortment                   0
# CompetitionDistance          0
# CompetitionOpenSinceMonth    0
# CompetitionOpenSinceYear     0
# Promo2                       0
# Promo2SinceWeek              0
# Promo2SinceYear              0
# PromoInterval                0
# dtype: int64

# %% [markdown]
# ### Check Outliers

# %%
store_data.describe()
# Out:
#             Store  CompetitionDistance  ...  Promo2SinceWeek  Promo2SinceYear
# count  1115.00000          1115.000000  ...      1115.000000       1115.00000
# mean    558.00000          5404.901079  ...        11.595516       1029.75157
# std     322.01708          7652.849306  ...        15.925223       1006.53886
# min       1.00000            20.000000  ...        -1.000000         -1.00000
# 25%     279.50000           720.000000  ...        -1.000000         -1.00000
# 50%     558.00000          2330.000000  ...         1.000000       2009.00000
# 75%     836.50000          6875.000000  ...        22.000000       2012.00000
# max    1115.00000         75860.000000  ...        50.000000       2015.00000
#
# [8 rows x 7 columns]

# %% [markdown]
# Let's try to process the CompetitionDistance Outliers

# %%
from scipy import stats
store_data['CD_zscore'] = np.abs(stats.zscore(store_data['CompetitionDistance'].to_numpy()))
store_data.head()
# Out:
#    Store StoreType Assortment  ...  Promo2SinceYear    PromoInterval  CD_zscore
# 0      1         c          a  ...             -1.0               -1   0.540551
# 1      2         a          a  ...           2010.0  Jan,Apr,Jul,Oct   0.632061
# 2      3         a          a  ...           2011.0  Jan,Apr,Jul,Oct   1.140623
# 3      4         c          c  ...             -1.0               -1   0.625525
# 4      5         a          a  ...             -1.0               -1   3.203525
#
# [5 rows x 11 columns]

# %%
store_data_cleaned = store_data[store_data['CD_zscore'] < 3]
store_data_cleaned.describe()
# Out:
#              Store  CompetitionDistance  ...  Promo2SinceYear    CD_zscore
# count  1093.000000          1093.000000  ...      1093.000000  1093.000000
# mean    559.150046          4725.402290  ...      1050.498628     0.608184
# std     322.261812          5825.426321  ...      1005.830924     0.466511
# min       1.000000            20.000000  ...        -1.000000     0.000000
# 25%     279.000000           700.000000  ...        -1.000000     0.349713
# 50%     560.000000          2280.000000  ...      2009.000000     0.553650
# 75%     839.000000          6360.000000  ...      2012.000000     0.673895
# max    1115.000000         27650.000000  ...      2015.000000     2.908078
#
# [8 rows x 8 columns]

# %%
store_data = store_data_cleaned

# %%
train_data.describe()
# Out:
#               Store     DayOfWeek  ...         Promo  SchoolHoliday
# count  1.017209e+06  1.017209e+06  ...  1.017209e+06   1.017209e+06
# mean   5.584297e+02  3.998341e+00  ...  3.815145e-01   1.786467e-01
# std    3.219087e+02  1.997391e+00  ...  4.857586e-01   3.830564e-01
# min    1.000000e+00  1.000000e+00  ...  0.000000e+00   0.000000e+00
# 25%    2.800000e+02  2.000000e+00  ...  0.000000e+00   0.000000e+00
# 50%    5.580000e+02  4.000000e+00  ...  0.000000e+00   0.000000e+00
# 75%    8.380000e+02  6.000000e+00  ...  1.000000e+00   0.000000e+00
# max    1.115000e+03  7.000000e+00  ...  1.000000e+00   1.000000e+00
#
# [8 rows x 7 columns]

# %% [markdown]
# ## Data Visualization

# %%
store_1_data = train_data[train_data['Store'] == 1].sort_values('Date', ascending=True).reset_index(drop=False)
store_1_data['Date'] = pd.to_datetime(store_1_data['Date'])
store_1_data.head()
# Out:
#      index  Store  DayOfWeek  ... Promo  StateHoliday  SchoolHoliday
# 0  1016095      1          2  ...     0             a              1
# 1  1014980      1          3  ...     0             0              1
# 2  1013865      1          4  ...     0             0              1
# 3  1012750      1          5  ...     0             0              1
# 4  1011635      1          6  ...     0             0              1
#
# [5 rows x 10 columns]

# %%
store_1_data_open = store_1_data[store_1_data['Open']== 1] # If store open
store_1_data_open.head()
# Out:
#      index  Store  DayOfWeek  ... Promo  StateHoliday  SchoolHoliday
# 1  1014980      1          3  ...     0             0              1
# 2  1013865      1          4  ...     0             0              1
# 3  1012750      1          5  ...     0             0              1
# 4  1011635      1          6  ...     0             0              1
# 6  1009405      1          1  ...     1             0              1
#
# [5 rows x 10 columns]

# %% [markdown]
# ### Time series

# %%
fig, axes = plt.subplots(4, figsize = (20,32))

for ax in axes:
  ax.patch.set_alpha(0)

axes[0].plot(store_1_data['Date'], store_1_data['Sales'], color = 'C1')
axes[0].grid(True, linewidth=0.2, color='black', linestyle='-')
axes[0].set_title("Time Serie of Sales for the Store n°1 (open+closed)")

axes[1].plot(store_1_data_open['Date'], store_1_data_open['Sales'], color = 'C1')
axes[1].grid(True, linewidth=0.2, color='black', linestyle='-')
axes[1].set_title("Time Serie of Sales for the Store n°1 (open)")

axes[2].plot(store_1_data['Date'], store_1_data['Customers'], color = 'C2')
axes[2].grid(True, linewidth=0.2, color='black', linestyle='-')
axes[2].set_title('Time Serie of Customers for the Store n°1')

axes[3].plot(store_1_data_open['Date'], store_1_data_open['Customers'], color = 'C2')
axes[3].grid(True, linewidth=0.2, color='black', linestyle='-')
axes[3].set_title('Time Serie of Customers for the Store n°1')

fig.show()

# %% [markdown]
# ### Time series - Aggregations

# %% [markdown]
# #### Groupby Day - average sales and customers

# %%
combined_data = store_data.merge(train_data, on=['Store'])
combined_data['Date'] = pd.to_datetime(combined_data['Date'])
combined_data.set_index('Date', inplace=True)
combined_data.head()
# Out:
#             Store StoreType Assortment  ...  Promo  StateHoliday  SchoolHoliday
# Date                                    ...
# 2015-07-31      1         c          a  ...      1             0              1
# 2015-07-30      1         c          a  ...      1             0              1
# 2015-07-29      1         c          a  ...      1             0              1
# 2015-07-28      1         c          a  ...      1             0              1
# 2015-07-27      1         c          a  ...      1             0              1
#
# [5 rows x 18 columns]

# %%
grouped_df = combined_data.groupby(['Date']).agg({'Sales': 'sum', 'Customers':'sum'})
grouped_df.reset_index(level = 0, inplace=True)
grouped_df['Date'] = pd.to_datetime(grouped_df['Date']) - pd.to_timedelta(7, unit='d')
grouped_df.head()
# Out:
#         Date    Sales  Customers
# 0 2012-12-25    97235      19491
# 1 2012-12-26  6813737     818224
# 2 2012-12-27  6222603     746265
# 3 2012-12-28  6515975     768181
# 4 2012-12-29  5858812     676909

# %%
# To comment if daily graph
grouped_df = grouped_df.groupby([pd.Grouper(key=('Date'), freq='W-MON')]).agg({'Sales':'sum', 'Customers': 'sum'})

# %%
scaler = MinMaxScaler()
grouped_df[['Sales', 'Customers']] = scaler.fit_transform(grouped_df[['Sales', 'Customers']])
grouped_df.head()
# Out:
#                Sales  Customers
# Date
# 2012-12-31  0.181659   0.241171
# 2013-01-07  0.345530   0.417701
# 2013-01-14  0.188618   0.286203
# 2013-01-21  0.320214   0.389426
# 2013-01-28  0.314510   0.390545

# %%
fig, ax = plt.subplots()
ax.plot(grouped_df.index, grouped_df['Sales'], label='Sales')
ax.plot(grouped_df.index, grouped_df['Customers'], label = 'Customers')
ax.grid(True, linewidth=0.2, color='black', linestyle='-')
ax.legend()
ax.set_title('Total Sales & Total Customers over all stores - Week Aggregation')
ax.patch.set_alpha(0)
fig.show()

# %% [markdown]
# #### Groupby Day & StoreType - sales & customers

# %%
grouped_df_2 = combined_data.groupby(['Date', 'StoreType']).agg({'Sales' : 'mean', 'Customers' : 'mean'})
grouped_df_2.reset_index(level=1, inplace=True)
grouped_df_2.reset_index(level=0, inplace=True)
grouped_df_2.head()
# Out:
#         Date StoreType        Sales    Customers
# 0 2013-01-01         a     4.960751     0.907850
# 1 2013-01-01         b  5548.705882  1115.235294
# 2 2013-01-01         c     0.000000     0.000000
# 3 2013-01-01         d     0.000000     0.000000
# 4 2013-01-02         a  6520.747871   817.955707

# %%
grouped_df_2 = grouped_df_2.groupby(['StoreType', pd.Grouper(key=('Date'), freq='W-MON')]).agg({'Sales':'mean', 'Customers': 'mean'})
grouped_df_2.reset_index(level=0, inplace=True)
grouped_df_2.head()
# Out:
#            StoreType        Sales   Customers
# Date
# 2013-01-07         a  4790.439513  564.060333
# 2013-01-14         a  5794.124605  670.770747
# 2013-01-21         a  4880.471404  594.608907
# 2013-01-28         a  5610.962765  651.111706
# 2013-02-04         a  5609.295936  653.311755

# %%
store_types = np.unique(grouped_df_2['StoreType'])
fig, ax = plt.subplots()
for store_type in store_types:
  tmp = grouped_df_2[grouped_df_2['StoreType'] == store_type].sort_values('Date')
  ax.plot(tmp.index[:365], tmp['Sales'][:365], label = store_type)
ax.grid(True, linewidth=0.2, color='black', linestyle='-')
ax.legend()
ax.set_title('Average Sales by store type')
ax.patch.set_alpha(0)
fig.show()

# %%
store_types = np.unique(grouped_df_2['StoreType'])
fig, ax = plt.subplots()
for store_type in store_types:
  tmp = grouped_df_2[grouped_df_2['StoreType'] == store_type].sort_values('Date')
  ax.plot(tmp.index[:365], tmp['Customers'][:365], label = store_type)
  #ax.fill_between(tmp.index[:365], 0, tmp['Customers'][:365])
ax.grid(True, linewidth=0.2, color='black', linestyle='-')
ax.legend()
ax.set_title('Average Nb of Customers by store type')
ax.patch.set_alpha(0)
fig.show()

# %% [markdown]
# #### Groupby Day & Store Assortment - Average Sales & Customers

# %%
grouped_df_3 = combined_data.groupby(['Date', 'Assortment']).agg({'Sales' : 'mean', 'Customers' : 'mean'})
grouped_df_3.reset_index(level=1, inplace=True)
grouped_df_3.head()
# Out:
#            Assortment        Sales    Customers
# Date
# 2013-01-01          a    68.175468    11.618399
# 2013-01-01          b  5090.111111  1162.666667
# 2013-01-01          c    22.993952     4.449597
# 2013-01-02          a  6142.818027   761.447279
# 2013-01-02          b  5108.666667  1431.111111

# %%
grouped_df_3.reset_index(level=0, inplace=True)
grouped_df_3 = grouped_df_3.groupby(['Assortment', pd.Grouper(key=('Date'), freq='W-MON')]).agg({'Sales' : 'mean', 'Customers' : 'mean'})
grouped_df_3.reset_index(level=0, inplace=True)
grouped_df_3.head()
# Out:
#            Assortment        Sales   Customers
# Date
# 2013-01-07          a  4648.222832  539.174106
# 2013-01-14          a  5642.150875  640.328474
# 2013-01-21          a  4724.348639  565.967930
# 2013-01-28          a  5512.216958  624.703353
# 2013-02-04          a  5398.172012  618.528912

# %%
store_types = np.unique(grouped_df_3['Assortment'])
fig, ax = plt.subplots()
for store_type in store_types:
  tmp = grouped_df_3[grouped_df_3['Assortment'] == store_type].sort_values('Date')
  ax.plot(tmp.index[:365], tmp['Sales'][:365], label = store_type)
ax.grid(True, linewidth=0.2, color='black', linestyle='-')
ax.legend()
ax.set_title('Average Sales by store assortment')
ax.patch.set_alpha(0)
fig.show()

# %%
store_types = np.unique(grouped_df_3['Assortment'])
fig, ax = plt.subplots()
for store_type in store_types:
  tmp = grouped_df_3[grouped_df_3['Assortment'] == store_type].sort_values('Date')
  ax.plot(tmp.index[:365], tmp['Customers'][:365], label = store_type)
ax.grid(True, linewidth=0.2, color='black', linestyle='-')
ax.legend()
ax.set_title('Average Customers by store assortment')
ax.patch.set_alpha(0)
fig.show()

# %% [markdown]
# #### Groupby Weeks, StoreType - Sales and Customers

# %%
combined_data2 = combined_data.reset_index(level=0)
combined_data2['Date'] = pd.to_datetime(combined_data2['Date']) 
grouped_df_4 = combined_data2.groupby(['StoreType', pd.Grouper(key='Date', freq='W-MON')]).agg({'Sales':'sum', 'Customers': 'sum'}).reset_index().sort_values('Date')
grouped_df_4.head()
# Out:
#     StoreType       Date     Sales  Customers
# 0           a 2013-01-07  19683911    2317723
# 135         b 2013-01-07    844517     171018
# 270         c 2013-01-07   4862164     605239
# 405         d 2013-01-07  10890765    1001192
# 136         b 2013-01-14    949433     188299

# %%
store_types = np.unique(grouped_df_4['StoreType'])
fig, ax = plt.subplots()
for store_type in store_types:
  tmp = grouped_df_4[grouped_df_4['StoreType'] == store_type].sort_values('Date')
  ax.plot(tmp['Date'], tmp['Sales'], label = store_type)
ax.grid(True, linewidth=0.2, color='black', linestyle='-')
ax.legend()
ax.set_title('Weekly Total Sales by store type')
ax.patch.set_alpha(0)
fig.show()

# %%
store_types = np.unique(grouped_df_4['StoreType'])
fig, ax = plt.subplots()
for store_type in store_types:
  tmp = grouped_df_4[grouped_df_4['StoreType'] == store_type].sort_values('Date')
  ax.plot(tmp['Date'], tmp['Customers'], label = store_type)
ax.grid(True, linewidth=0.2, color='black', linestyle='-')
ax.legend()
ax.set_title('Weekly Total Customers by store type')
ax.patch.set_alpha(0)
fig.show()

# %% [markdown]
# #### Groupby Months, StoreType - Sales & Customers

# %%
combined_data2 = combined_data.reset_index(level=0)
combined_data2['Date'] = pd.to_datetime(combined_data2['Date'])
grouped_df_4 = combined_data2.groupby(['StoreType', pd.Grouper(key='Date', freq='MS')]).agg({'Sales':'sum', 'Customers': 'sum'}).reset_index().sort_values('Date')
grouped_df_4.head()
# Out:
#    StoreType       Date     Sales  Customers
# 0          a 2013-01-01  96756432   11444531
# 31         b 2013-01-01   4124131     840933
# 62         c 2013-01-01  23339869    2889361
# 93         d 2013-01-01  52755554    4857652
# 32         b 2013-02-01   4053576     821128

# %%
store_types = np.unique(grouped_df_4['StoreType'])
fig, ax = plt.subplots()
for store_type in store_types:
  tmp = grouped_df_4[grouped_df_4['StoreType'] == store_type].sort_values('Date')
  ax.plot(tmp['Date'], tmp['Sales'], label = store_type)
ax.grid(True, linewidth=0.2, color='black', linestyle='-')
ax.legend()
ax.set_title('Monthly Total Sales by store type')
ax.patch.set_alpha(0)
fig.show()

# %% [markdown]
# #### Groupby DayOfTheWeek & Store_types - Sales

# %%
combined_data_noholidays = combined_data[combined_data['SchoolHoliday'] == 0]
grouped_df_5 = combined_data_noholidays.groupby(['DayOfWeek', 'StoreType'])['Sales'].sum().reset_index(name='Total Sales')
grouped_df_5.head()
# Out:
#    DayOfWeek StoreType  Total Sales
# 0          1         a    463653089
# 1          1         b     18778943
# 2          1         c    109790150
# 3          1         d    252833081
# 4          2         a    419035122

# %%
store_types = np.unique(grouped_df_5['StoreType'])
fig, ax = plt.subplots()
for store_type in store_types:
  tmp = grouped_df_5[grouped_df_5['StoreType'] == store_type].sort_values('DayOfWeek')
  ax.plot(tmp['DayOfWeek'], tmp['Total Sales'], label = store_type)
ax.grid(True, linewidth=0.2, color='black', linestyle='-')
ax.legend()
ax.set_title('Total Sales per day of week')
ax.patch.set_alpha(0)
fig.show()

# %%
combined_data_holidays = combined_data[combined_data['SchoolHoliday'] == 1]
grouped_df_5 = combined_data_holidays.groupby(['DayOfWeek', 'StoreType'])['Sales'].sum().reset_index(name='Total Sales')
grouped_df_5.head()
# Out:
#    DayOfWeek StoreType  Total Sales
# 0          1         a    143745362
# 1          1         b      5707937
# 2          1         c     35201592
# 3          1         d     78288986
# 4          2         a    137561865

# %%
store_types = np.unique(grouped_df_5['StoreType'])
fig, ax = plt.subplots()
for store_type in store_types:
  tmp = grouped_df_5[grouped_df_5['StoreType'] == store_type].sort_values('DayOfWeek')
  ax.plot(tmp['DayOfWeek'], tmp['Total Sales'], label = store_type)
ax.grid(True, linewidth=0.2, color='black', linestyle='-')
ax.legend()
ax.set_title('Total Sales per day of week')
ax.patch.set_alpha(0)
fig.show()

# %% [markdown]
# #### Groupby DayOfTheWeek & Store_types - Sales

# %%
grouped_df_6 = combined_data.groupby(['DayOfWeek', 'Assortment'])['Sales'].sum().reset_index(name='Total Sales')
grouped_df_6.head()
# Out:
#    DayOfWeek Assortment  Total Sales
# 0          1          a    571402107
# 1          1          b     10368068
# 2          1          c    526228965
# 3          2          a    517759908
# 4          2          b      9671086

# %%
assortments = np.unique(grouped_df_6['Assortment'])
fig, ax = plt.subplots()
for assortment in assortments:
  tmp = grouped_df_6[grouped_df_6['Assortment'] == assortment].sort_values('DayOfWeek')
  ax.plot(tmp['DayOfWeek'], tmp['Total Sales'], label = assortment)
ax.grid(True, linewidth=0.2, color='black', linestyle='-')
ax.legend()
ax.set_title('Total Sales per day of week')
ax.patch.set_alpha(0)
fig.show()

# %% [markdown]
# #### Groupby DayOfWeek - Nb stores

# %%
grouped_df_7 = combined_data.groupby(['DayOfWeek', 'StoreType', 'Open'])['Store'].count().reset_index(name='NB_stores')
grouped_df_7.head()
# Out:
#    DayOfWeek StoreType  Open  NB_stores
# 0          1         a     0       3817
# 1          1         a     1      72657
# 2          1         b     0         37
# 3          1         b     1       2215
# 4          1         c     0        997

# %%
store_types = np.unique(grouped_df_7['StoreType'])
fig, axes = plt.subplots(4, figsize=(20, 32))
for ax in axes:
  ax.patch.set_alpha(0)
colors = ['r', 'g', 'b', 'purple']
for i in range(0, 4):
  tmp = grouped_df_7[(grouped_df_7['StoreType'] == store_types[i]) & (grouped_df_7['Open'] == 1)].sort_values('DayOfWeek')
  axes[i].plot(tmp['DayOfWeek'], tmp['NB_stores'], colors[i], label = store_types[i])
  axes[i].grid(True, linewidth=0.2, color='black', linestyle='-')
  axes[i].legend()
  axes[i].set_title('Total Open Shops of type : ' + str(store_types[i]))
fig.show()

# %% [markdown]
# #### Groupby Promo

# %%
promo = combined_data.groupby(['DayOfWeek', 'StoreType', 'Promo'])['Sales'].count().reset_index(name='NB_stores')
promo
# Out:
#     DayOfWeek StoreType  Promo  NB_stores
# 0           1         a      0      35386
# 1           1         a      1      41088
# 2           1         b      0       1042
# 3           1         b      1       1210
# 4           1         c      0       8884
# 5           1         c      1      10316
# 6           1         d      0      20294
# 7           1         d      1      23562
# 8           2         a      0      35972
# 9           2         a      1      41004
# 10          2         b      0       1059
# 11          2         b      1       1209
# 12          2         c      0       9030
# 13          2         c      1      10302
# 14          2         d      0      20637
# 15          2         d      1      23481
# 16          3         a      0      35973
# 17          3         a      1      41004
# 18          3         b      0       1059
# 19          3         b      1       1209
# 20          3         c      0       9030
# ...

# %%
store_types = np.unique(promo['StoreType'])
fig, axes = plt.subplots(4, figsize=(20, 32))
for ax in axes:
  ax.patch.set_alpha(0)
colors = ['r', 'g', 'b', 'purple']
for i in range(0, 4):
  tmp = promo[(promo['StoreType'] == store_types[i]) & (promo['Promo'] == 1)].sort_values('DayOfWeek')
  axes[i].plot(tmp['DayOfWeek'], tmp['NB_stores'], colors[i], label = store_types[i])
  axes[i].grid(True, linewidth=0.2, color='black', linestyle='-')
  axes[i].legend()
  axes[i].set_title('Total Open Shops of type : ' + str(store_types[i]))
fig.show()

# %% [markdown]
# ### Scatter Plots

# %%
combined_data.head()
# Out:
#             Store StoreType Assortment  ...  Promo  StateHoliday  SchoolHoliday
# Date                                    ...
# 2015-07-31      1         c          a  ...      1             0              1
# 2015-07-30      1         c          a  ...      1             0              1
# 2015-07-29      1         c          a  ...      1             0              1
# 2015-07-28      1         c          a  ...      1             0              1
# 2015-07-27      1         c          a  ...      1             0              1
#
# [5 rows x 18 columns]

# %%
scatter_df = combined_data[combined_data['Open'] == 1]
fig, ax = plt.subplots()
store_types = np.unique(scatter_df['StoreType'])
for store_types in store_types:
  tmp = scatter_df[scatter_df['StoreType'] == store_types]
  ax.scatter(tmp['Customers'], tmp['Sales'], label = store_types)
ax.patch.set_alpha(0)
ax.legend()
ax.set_title('Scatterplot of customers by sales for store colored by types')
fig.show()

# %%
fig, ax = plt.subplots()
promo_type = np.unique(scatter_df['Promo'])
for promo in promo_type:
  tmp = scatter_df[scatter_df['Promo'] == promo]
  ax.scatter(tmp['Customers'], tmp['Sales'] , label = promo)
ax.patch.set_alpha(0)
ax.legend()
ax.set_title('Scatterplot of customers by sales for store colored by types')
fig.show()

# %% [markdown]
# ### Classical Plots

# %%
promo1 = combined_data[(combined_data['Promo'] == 0) & (combined_data['Open'] == 1)]
promo2 = combined_data[(combined_data['Promo'] == 1) & (combined_data['Open'] == 1)]

promo1.reset_index(level=0, inplace=True)
promo2.reset_index(level=0, inplace=True)
promo1 = promo1.groupby([pd.Grouper(key='Date', freq='W-MON')])['Sales'].mean().reset_index(name = "Avg Sales")
promo2 = promo2.groupby([pd.Grouper(key='Date', freq='W-MON')])['Sales'].mean().reset_index(name = "Avg Sales")

# %%
fig, ax = plt.subplots()
ax.plot(promo1['Date'], promo1['Avg Sales'], label = 'without promo')
ax.plot(promo2['Date'], promo2['Avg Sales'], label = 'with promo')
ax.patch.set_alpha(0)
ax.legend()
ax.set_title('Impact of promos on Sales Performance')
fig.show()

# %%
promo1 = combined_data[(combined_data['Promo'] == 0) & (combined_data['Open'] == 1)]
promo2 = combined_data[(combined_data['Promo'] == 1) & (combined_data['Open'] == 1)]
promo1.reset_index(level=0, inplace=True)
promo2.reset_index(level=0, inplace=True)
promo1 = promo1.groupby([pd.Grouper(key='Date', freq='W-MON')])['Customers'].mean().reset_index(name = "Mean Customers")
promo2 = promo2.groupby([pd.Grouper(key='Date', freq='W-MON')])['Customers'].mean().reset_index(name = "Mean Customers")

# %%
fig, ax = plt.subplots()
ax.plot(promo1['Date'], promo1['Mean Customers'], label = 'without promo')
ax.plot(promo2['Date'], promo2['Mean Customers'], label = 'with promo')
ax.patch.set_alpha(0)
ax.legend()
ax.set_title('Impact of promos on Customers')
fig.show()

# %%
tmp = combined_data.groupby(['CompetitionDistance'])['Customers'].mean().reset_index(name='Avg Sales')
fig, ax = plt.subplots()
ax.plot(tmp['CompetitionDistance'], tmp['Avg Sales'])
ax.patch.set_alpha(0)
fig.show()

# %% [markdown]
# ### Others

# %%
combined_data.head()
# Out:
#             Store StoreType Assortment  ...  Promo  StateHoliday  SchoolHoliday
# Date                                    ...
# 2015-07-31      1         c          a  ...      1             0              1
# 2015-07-30      1         c          a  ...      1             0              1
# 2015-07-29      1         c          a  ...      1             0              1
# 2015-07-28      1         c          a  ...      1             0              1
# 2015-07-27      1         c          a  ...      1             0              1
#
# [5 rows x 18 columns]

# %%
stores = combined_data.groupby(['StoreType'])['Store'].nunique().reset_index(name='NB Stores')
stores.head()
# Out:
#   StoreType  NB Stores
# 0         a        587
# 1         b         17
# 2         c        146
# 3         d        343

# %%
fig, ax = plt.subplots()
ax.bar(stores['StoreType'], stores['NB Stores'], color=color_list[1])
ax.patch.set_alpha(0)
fig.show()

# %%
assortment = combined_data.groupby(['Assortment'])['Store'].nunique().reset_index(name='NB Stores')
assortment.head()
# Out:
#   Assortment  NB Stores
# 0          a        588
# 1          b          9
# 2          c        496

# %%
fig, ax = plt.subplots()
ax.bar(assortment['Assortment'], assortment['NB Stores'], color=color_list[1])
ax.patch.set_alpha(0)
fig.show()
